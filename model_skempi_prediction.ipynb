# %%
import pandas as pd
# Out:
# C:\Users\sh_su\AppData\Local\Temp\ipykernel_23040\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('mutant_variants.csv')

# %%
df['Rec'] = 'RHPHPHLSFMAIPPKK'

# %%
df['Label'] = 1

# %%
df
# Out:
#                        Mutant               Rec  Label
# 0       LFDTGSSAAAATIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 1       LFDTGSSAAACTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 2       LFDTGSSAAADTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 3       LFDTGSSAAAETIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 4       LFDTGSSAAAFTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# ...                       ...               ...    ...
# 159994  LFDTGSSYYYSTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 159995  LFDTGSSYYYTTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 159996  LFDTGSSYYYVTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 159997  LFDTGSSYYYWTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
# 159998  LFDTGSSYYYYTIDTGTNFFI  RHPHPHLSFMAIPPKK      1
#
# [159999 rows x 3 columns]

# %%
import pickle

filename = 'model.pkl'
with open(filename, 'rb') as file:
    loaded_model = pickle.load(file)

# %%
from DeepPurpose import utils, dataset
from DeepPurpose import CompoundPred as models

new_data = utils.data_process(X_target = df['Rec'], X_target_ = df['Mutant'], y = df['Label'], 
                              target_encoding = target_encoding, 
                              split_method = 'no_split')
# Out:
# Protein Protein Interaction Prediction Mode...
# in total: 159999 protein-protein pairs
# encoding protein...
# unique target sequence: 1
# encoding protein...
# unique target sequence: 159999

# %%
# Make predictions on the new dataset
predictions = loaded_model.predict(new_data)

# If you want to see the predictions
print(predictions)
# Out:
# predicting...
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
len(predictions)
# Out:
# 159999

# %%
df['Predicted'] = predictions

# %%
df
# Out:
#                        Mutant               Rec  Label  Predicted
# 0       LFDTGSSAAAATIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.014655
# 1       LFDTGSSAAACTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.025762
# 2       LFDTGSSAAADTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.023637
# 3       LFDTGSSAAAETIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.013779
# 4       LFDTGSSAAAFTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.009974
# ...                       ...               ...    ...        ...
# 159994  LFDTGSSYYYSTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.069566
# 159995  LFDTGSSYYYTTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.103061
# 159996  LFDTGSSYYYVTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.114645
# 159997  LFDTGSSYYYWTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.124221
# 159998  LFDTGSSYYYYTIDTGTNFFI  RHPHPHLSFMAIPPKK      1   0.104373
#
# [159999 rows x 4 columns]

# %%
df = pd.read_csv('mut_set2.csv')

# %%
df['Rec'] = 'RHPHPHLSFMAIPPKK'
df['Label'] = 1

# %%
from DeepPurpose import utils, dataset
from DeepPurpose import CompoundPred as models

new_data = utils.data_process(X_target = df['Rec'], X_target_ = df['Mutant'], y = df['Label'], 
                              target_encoding = target_encoding, 
                              split_method = 'no_split')
# Out:
# Protein Protein Interaction Prediction Mode...
# in total: 4140 protein-protein pairs
# encoding protein...
# unique target sequence: 1
# encoding protein...
# unique target sequence: 4002

# %%
# Make predictions on the new dataset
predictions = loaded_model.predict(new_data)

# If you want to see the predictions
print(predictions)
# Out:
# predicting...
# ...

# %%
len(predictions)
# Out:
# 4140

# %%
df['Predicted'] = predictions

# %%
df.to_csv('predicted_skmp_mut2')

# %%
df = pd.read_csv('sorted_pdb_mut2_inter.csv')

# %%
df
# Out:
#     level_0  index Target Sequence 1      Target Sequence 2  Label  \
# 0         0   2428  RHPHPHLSFMAIPPKK  LFDTGSSADDSTKDTGTNFFI      1
# 1         1    388  RHPHPHLSFMAIPPKK  LFDTGSSVEDTTKDTGTNFFI      1
# 2         2   1654  RHPHPHLSFMAIPPKK  LFDTGSSGDEMTRDTGTNFFI      1
# 3         3   1174  RHPHPHLSFMAIPPKK  LFDTGSSAEDYTRDTGTNFFI      1
# 4         4   1048  RHPHPHLSFMAIPPKK  LFDTGSSAEESTKDTGTNFFI      1
# ..      ...    ...               ...                    ...    ...
# 91       91    148  RHPHPHLSFMAIPPKK  LFDTGSSGEDTTKDTGTNFFI      1
# 92       92     34  RHPHPHLSFMAIPPKK  LFDTGSSADESTRDTGTNFFI      1
# 93       93    694  RHPHPHLSFMAIPPKK  LFDTGSSAEETTRDTGTNFFI      1
# 94       94    988  RHPHPHLSFMAIPPKK  LFDTGSSGEETTKDTGTNFFI      1
# 95       95   2494  RHPHPHLSFMAIPPKK  LFDTGSSADEMTRDTGTNFFI      1
#
#     predicted_value
# 0          1.352591
# 1          1.352591
# 2          1.352591
# 3          1.352591
# 4          1.352591
# ..              ...
# ...

# %%
from DeepPurpose import utils, dataset
from DeepPurpose import CompoundPred as models

new_data = utils.data_process(X_target = df['Target Sequence 1'], X_target_ = df['Target Sequence 2'], y = df['Label'], 
                              target_encoding = target_encoding, 
                              split_method = 'no_split')
# Out:
# Protein Protein Interaction Prediction Mode...
# in total: 96 protein-protein pairs
# encoding protein...
# unique target sequence: 1
# encoding protein...
# unique target sequence: 96

# %%
predictions = loaded_model.predict(new_data)
# Out:
# predicting...

# %%
df['Predicted'] = predictions

# %%
df.to_csv('predicted_pdb_skmp_mut2.csv', index=False)
